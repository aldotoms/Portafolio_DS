# %% [markdown]
# # Hola &#x1F600;,
#
# Soy **Hesus Garcia** – **"Soy el único Hesus que conoces (y probablemente conocerás) 🌟"** – Sí, como "Jesús", pero con una H que me hace único. Puede sonar raro, pero créeme, ¡no lo olvidarás! Como tu revisor en Triple-Ten, estoy aquí para guiarte y ayudarte a mejorar tu código. Si algo necesita un ajuste, no hay de qué preocuparse; ¡aquí estoy para hacer que tu trabajo brille con todo su potencial! ✨
#
# Cada vez que encuentre un detalle importante en tu código, te lo señalaré para que puedas corregirlo y así te prepares para un ambiente de trabajo real, donde el líder de tu equipo actuaría de manera similar. Si en algún momento no logras solucionar el problema, te daré más detalles para ayudarte en nuestra próxima oportunidad de revisión.
#
# Es importante que cuando encuentres un comentario, **no los muevas, no los modifiques, ni los borres**.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis de datos o al proyecto. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Este código está correcto, pero se puede optimizar. Considera implementar mejoras para que sea más eficiente y fácil de leer. Esto fortalecerá la calidad de tu proyecto.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>A resolver</b> ❗ - Aquí hay un problema o error en el código que es necesario corregir para aprobar esta sección. Por favor, revisa y corrige este punto, ya que es fundamental para la validez del análisis y la precisión de los resultados.
#
# </div>
#
# ---
#
# Al final de cada revisión, recibirás un **Comentario General del Revisor** que incluirá:
#
# - **Aspectos positivos:** Un resumen de los puntos fuertes de tu proyecto.
# - **Áreas de mejora:** Sugerencias sobre aspectos donde puedes mejorar.
# - **Temas adicionales para investigar:** Ideas de temas opcionales que puedes explorar por tu cuenta para desarrollar aún más tus habilidades.
#
# Estos temas adicionales no son obligatorios en esta etapa, pero pueden serte útiles para profundizar en el futuro.
#
# ---
#
#
# Esta estructura en viñetas facilita la lectura y comprensión de cada parte del comentario final.
#
# También puedes responderme de la siguiente manera si tienes alguna duda o quieres aclarar algo específico:
#
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta sobre el comentario.
#
# </div>
#
#
# **¡Empecemos!** &#x1F680;

# %% [markdown]
# # PROYECTO FINAL_Sprint 19_Plan de Trbajo

# %% [markdown]
# ## Descripción del proyecto
#
# Al operador de telecomunicaciones Interconnect le gustaría poder pronosticar su tasa de cancelación de clientes. Si se descubre que un usuario o usuaria planea irse, se le ofrecerán códigos promocionales y opciones de planes especiales. El equipo de marketing de Interconnect ha recopilado algunos de los datos personales de sus clientes, incluyendo información sobre sus planes y contratos.
#
# ### Servicios de Interconnect
#
# Interconnect proporciona principalmente dos tipos de servicios:
#
# 1. Comunicación por teléfono fijo. El teléfono se puede conectar a varias líneas de manera simultánea.
#
# 2. Internet. La red se puede configurar a través de una línea telefónica (DSL, *línea de abonado digital*) o a través de un cable de fibra óptica.
#
# Algunos otros servicios que ofrece la empresa incluyen:
#
# - **Seguridad en Internet**: software antivirus (*ProtecciónDeDispositivo*) y un bloqueador de sitios web maliciosos (*SeguridadEnLínea*).
#
# - Una línea de **soporte técnico** (*SoporteTécnico*).
#
# - **Almacenamiento** de archivos en la nube y backup de datos (*BackupOnline*).
#
# - **Streaming** de TV (*StreamingTV*) y directorio de películas (*StreamingPelículas*)
#
# La clientela puede elegir entre un pago mensual o firmar un contrato de 1 o 2 años. Puede utilizar varios métodos de pago y recibir una factura electrónica después de una transacción.
#
# ### Descripción de los datos
#
# Los datos consisten en archivos obtenidos de diferentes fuentes:
#
# - `contract.csv` — información del contrato;
#
# - `personal.csv` — datos personales del cliente;
#
# - `internet.csv` — información sobre los servicios de Internet;
#
# - `phone.csv` — información sobre los servicios telefónicos.
#
# En cada archivo, la columna `customerID` (ID de cliente) contiene un código único asignado a cada cliente. La información del contrato es válida a partir del 1 de febrero de 2020.

# %% [markdown]
# ## Plan de Trabajo
#
# ### 1. Importación de librerías y carga de datos
# El proyecto inicia con la importación de las librerías fundamentales para el análisis y manipulación de datos. Pandas y NumPy permitirán trabajar con estructuras tabulares y cálculos numéricos, mientras que Matplotlib y Seaborn facilitarán la creación de visualizaciones que apoyen la comprensión inicial de los datos. En esta etapa también se cargan los archivos en bruto, preparando el entorno para el análisis posterior.
#
# ### 2. Exploración de los datos (EDA)
# La exploración de datos busca comprender la estructura, calidad y comportamiento de la información disponible. Se utilizará Sweetviz para obtener una visión general rápida, complementada con análisis manual mediante Pandas y visualizaciones personalizadas. Se revisarán tipos de datos, estadísticas descriptivas, consistencia entre columnas, presencia de nulos, duplicados y valores atípicos, siempre considerando el contexto del negocio. Este análisis permitirá identificar patrones relevantes y preparar adecuadamente los datos para su transformación posterior, manteniendo copias de seguridad para preservar la integridad de la información original.
#
# ### 3. Preprocesamiento de los datos
# En esta fase se reorganizan y combinan los datasets utilizando sus llaves primarias, asegurando una estructura coherente para el modelado. Se generarán nuevas características relevantes, como la antigüedad del cliente, duración del contrato y montos asociados a los servicios contratados. Posteriormente, toda la información se integrará en un único dataframe que concentre las variables necesarias para el análisis predictivo. Este proceso sienta las bases para que los modelos puedan aprender patrones significativos relacionados con la cancelación de clientes.
#
# ### 4. Modelado de datos
# El modelado comienza con la definición del conjunto de características y la variable objetivo, seguido de la división del dataset en entrenamiento y prueba. Sobre el conjunto de entrenamiento se aplicarán técnicas de balanceo, escalado y selección de características mediante pipelines para evitar fuga de datos. Se entrenará un conjunto diverso de modelos, desde regresión logística hasta algoritmos de boosting, incluyendo un modelo Dummy como referencia mínima. CatBoost se evaluará tanto con como sin codificación categórica. PyCaret servirá como apoyo para comparar rápidamente el rendimiento de los modelos, mientras que la evaluación formal se basará en métricas como AUC‑ROC, Recall, Precision, F1 y la matriz de confusión.
#
# ### 5. Comparación de resultados y conclusiones finales
# Una vez entrenados todos los modelos, se realizará una comparación exhaustiva de su desempeño para identificar el que ofrezca el mejor equilibrio entre capacidad predictiva, estabilidad y utilidad práctica. Se documentarán las razones técnicas que justifican su selección, incluyendo la importancia de las variables y su comportamiento frente al desbalance de clases. Finalmente, se presentarán conclusiones generales del proyecto y recomendaciones para el despliegue en producción, abordando aspectos como monitoreo, actualización del modelo y oportunidades de mejora futura. Con ello, el proyecto se cerrará con una propuesta sólida y alineada a los objetivos estratégicos de Interconnect.

# %% [markdown]
# ## Plan de Trabajo (detallado)
#
# ### 1. Importación de librerías básicas para la revisión y manipulación de datos y visualización de gráficas; así como también la carga de los datos en bruto.
#     Librerías a utilizar:
#
#     - **Pandas**: para el manejo y análisis de estructura de datos.
#
#     - **Numpy**: para el cálculo numérico y análisis de datos.
#
#     - **Matplotlib**: para la creación de gráficas.
#
#     - **Seaborn**: para la visualización de los datos con mejores gráficas.
#
#
# ### 2. Exploración de los datos (EDA - Exploratory Data Analysis)
#
#    Se utilizará la librería de código abierto llamada `sweetviz` para una mejor exploración inicial de los datos y posible comparación de los datasets; sin embargo, de ser necesario se realiaran gráficos persobalizados con matplotlib y seaborn para profundizar alguna posible comparación de columnas, realizando agrupaciones y agregaciones de datos.
#
#    Para un mejor entendimiento del negocio, se revisarán a detalle los cuatro datasets proporcionados, revisando en cada uno las siguientes características:
#
#        a) Se revisará la información general y estadística, utilizando los métodos `.info()` y `.describe()`; así como también se revisará el encabezado `.head()` y una muestra aleatoria `.sample()` de cada uno de los datasets para el mejor entendimiento de los datos.
#
#        b) Se verificará que los tipos de datos (`dtypes`) sean los correctos, numéridos, categóricos, datetime; en caso de ser necesario serán corregidos.
#
#        c) Se creará un diccionario por cada dataset para entender qué información contiene cada uno, las columnas que contengan y su importancia para la creación del modelo.
#         También se revisarán los nombres de las columnas en cada dataset para ver si hay información similar entre ellos; se procesarán para que complan con "snake case" y homologarlas, esto ayudará en una posible y futura unión de tablas.
#
#        d) Se buscarán datos nulos o faltantes, se revisará el porcentaje que ocupan en cada uno de los datasets y se revisarán a detalle para ver si es conveniente imputarlos o bien crear una nueva categoría como "SinServicio" o "NoAplica", al ser un posible servicio no contratado.
#
#        e) Se buscarán datos duplicados, los cuales serán revisados a detalle para descartar que sean verdaderos duplicados y se analizará si es viable eliminarlos o mejor dejarlos; se revisará si se trata de registros válidos; por ejemplo, cambios de plan para el mismo usuario.
#
#        f) Se buscarán valores atípicos ("outliers") y se graficarán para un mejor entendimiento con gráficos de bigote, se analizarán y se decidirá si es conveniente dejarlos al ser un problema de rotación de clientes ("Churn") regularmente los valores extremos se tratan de clientes con consumos muy altos o muy bajos, y son los que explican el comprotamiento por lo que se evitará eliminarlos por completo.
#
#    **NOTA**: antes de realizar cambios y/o modificaciones, se realizará una copia `.copy()` de los datasets para mantenier los datos originales y los modificados, en variables independientes, por si es necesario revisar la información original en el futuro.
#
#
# ### 3. Preprocesamiento de los datos.
#
#    3.1 Las infromación revisada y verificada sin datos nulos, duplicados ni outliers, se agrupara y reacomodará de ser necesario en cada dataset para identificar las llaves primarias con las que servirá de unión entre tablas.
#
#    3.2 Se revisarán los datasets que contengan fechas para hacer Ingeniería de Características, identificando la antogüedad de los clientes ('Tenure') revisando el tiempo desde el inicio del contrato hasta la fecha de referencia (Tipo de Contrato), la duración del contrato (si es que aplica), creando nuevas columnas para cada característica nueva.
#
#    3.3 Así como también, se agrupará y se adicionarán columnas nuevas para obtener nueva información de los clientes, como por ejemplo el monto mensual y monto total pagado por cliente, dependiendo de los servicios que tenga activos (teléfono, mensajes, internet, etc.)
#
#    3.4 Después se unificará la mayor información posible en un sólo dataframe, guardándolo en una nueva variable para evitar una posible confusión con la demás data.
#
#
# ### 4. Modelado de Datos: separación de conjunto de entrenamiento, prueba y validación.
#
#    4.1 Primero se realizará una nueva copia del dataframe creado y se definirán el `'Target'` & `'Features'` con base en el análisis previo.
#
#    4.2 Separación de los sets en Entrenamiento (`train`) y Prueba (`test`), se utilizará el método `train_test_split()`.
#
#    4.3 Se revisará el balance de las clases y dependiendo de cómo se presente, se tomará la desición de utilizar alguna técnica como por ejemplo `oversampling` o `undersampling`; se revisará la distrbución de los datos para ver si es necesario un escalamiento, y se utilizará algún método como `StandarScaler, `MinMaxScaler`, MaxAbsScaler` y `RobustScaler`
#
#    4.4 Se explorarán las características numéricas, categóricas y de tiempo para tratar de identifcar cuales son las mejores características para el modelado, realizando gráficas de correlación con la finalidad de determinar las mejores características; de ser necesario se removerán características que no indiquen mucha corrrelación.
#
#    **NOTA**: Las técnicas de balanceo de clases, escalado y selección de características se aplicarán únicamente sobre el conjunto de entrenamiento, utilizando pipelines, para evitar fuga de datos (`data leakage`).
#
#    4.5 Para poder trabajar con diferentes modelos a la vez, se definirán varias funciones de acuerdo al siguiente orden.
#
#     a) Definición y Creación de los modelos a utilizar:
#
#     **Regresión Logistica**: LogisticRegression() modelo base y como referencia interpretable.
#
#     **Árbol de Decisión**: DecisionTreeClassifier() baseline “no lineal” sencillo.
#
#     **Bosque Aleatorio**: RandomForestClassifier() elección espscífica para churn.
#
#     **LightGMB**: LGBMClassifier() potente y rápido.
#
#     **CatBoost**: CatBoostClassifier() bueno para muchos categóricos.
#
#     **XGBoost**: XGBClassifier()
#
#     **Modelo Dummy**: DummyClassifier() predice siempre la clase mayoritaria o proporcional a las clases.
#
#    **NOTA**: Para LogisticRegression, DecisionTree, RandomForest, XGBoost, LightGBM, se realizará One Hot Encoding para variables catergóricas.
#          Para CatBoost, se evaluará la posibilidad de trabajar con las variables categóricas sin OHE, usando la funcionalidad nativa de la librería.
#
#    b) Se utilizará la librería llamada `pycaret` como herramienta de apoyo para la evaluación de diferentes modelos y revisar de manera rápida los diferentes métricos, con la intención de que las mejores configuraciones se reimplementarán (o, al menos, se entenderán) manualmente para tener control explícito sobre un futuro pipeline.
#
#    c) Función de Entrenamiento, utilizando el mismo set de `'train'` modificado para todos los modelos, a excepción de Catboost (sin OHE)
#
#    d) Función de Evaluación del Error
#
#        - La métrica principal será Métrica principal: AUC-ROC.
#
#        - Métricas adicionales: Recall, Precision, F1 y Matriz de Confusión
#
#            - Recall de la clase positiva (churn) → muy importante para negocio (no queremos dejar ir a quien sí se va).
#            - Precision → para saber qué tan limpios son los casos que marcamos como “se va”.
#            - F1-score → equilibrio entre precisión y recall.
#            - Matriz de confusión para al menos el mejor modelo.
#
#        - Criterios de evaluación:
#
#            AUC-ROC < 0.75 — 0 SP
#            0.75 ≤ AUC-ROC < 0.81 — 4 SP
#            0.81 ≤ AUC-ROC < 0.85 — 4.5 SP
#            0.85 ≤ AUC-ROC < 0.87 — 5 SP
#            0.87 ≤ AUC-ROC < 0.88 — 5.5 SP
#            AUC-ROC ≥ 0.88 — 6 SP
#
#
# ### 5. Comparación de resultados, selección del mejor modelo y conclusiones finales
#
#     Una vez entrenados todos los modelos definidos en el plan de trabajo, se realizará una comparación integral de su desempeño utilizando las métricas establecidas: AUC‑ROC como métrica principal y Recall, Precision, F1-score y Matriz de Confusión como métricas complementarias. Esta evaluación permitirá identificar no solo el modelo con mayor capacidad predictiva, sino también aquel que ofrezca un equilibrio adecuado entre sensibilidad y precisión para la clase positiva (churn), aspecto crítico para los objetivos del negocio.
#
#    Posteriormente, se seleccionará el modelo con el mejor rendimiento general, considerando tanto su desempeño cuantitativo como su estabilidad, interpretabilidad y viabilidad para ser desplegado en un entorno productivo. Se documentarán las razones técnicas que justifican su elección, incluyendo análisis de importancia de características, comportamiento frente al desbalance de clases y consistencia durante la validación cruzada.
#
#    Finalmente, se elaborarán las conclusiones generales del proyecto, destacando los hallazgos clave del análisis exploratorio, las variables más influyentes en la cancelación de clientes y las implicaciones estratégicas para el área de marketing. Se incluirán también recomendaciones para el despliegue en producción, tales como:
#
#    - Consideraciones para la actualización periódica del modelo.
#    - Necesidades de monitoreo de métricas en tiempo real.
#    - Posibles mejoras futuras (nuevas fuentes de datos, ajuste de hiperparámetros, modelos adicionales).
#    - Estrategias para integrar el modelo en los flujos operativos de retención de clientes.
#
#    Con ello se cerrará el proyecto con una visión clara, accionable y alineada a los objetivos de negocio de Interconnect, asegurando que el modelo seleccionado pueda aportar valor inmediato y sostenible en la predicción temprana de churn.

# %% [markdown]
# # Comentario General del Revisor
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
#
# El proyecto presenta un **plan de trabajo sólido, bien estructurado y alineado con los objetivos técnicos y de negocio planteados en el brief**. A lo largo de las distintas etapas del proceso analítico se observa una comprensión clara del problema de churn y de cómo abordarlo de forma sistemática y profesional.
#
# #### Puntos Positivos:
#
# * **Preparación y comprensión de los datos:** El plan contempla una exploración exhaustiva de los datasets, cuidando la calidad, consistencia y contextualización de la información antes de cualquier decisión analítica.
# * **Enfoque analítico por etapas:** La secuencia EDA: preprocesamiento, modelado, evaluación está bien definida y refleja buenas prácticas en proyectos de ciencia de datos.
# * **Rigor en el modelado:** La inclusión de pipelines, control de fuga de datos, balanceo de clases y un conjunto diverso de modelos demuestra criterio técnico y madurez analítica.
# * **Evaluación orientada al negocio:** La priorización de métricas como AUC-ROC y Recall para la clase churn conecta correctamente el desempeño del modelo con el impacto estratégico.
# * **Cierre accionable:** Las conclusiones y recomendaciones propuestas muestran una visión aplicada, pensando en despliegue, monitoreo y mejora continua.
#
# En conjunto, el plan de trabajo establece una **base clara, coherente y profesional** para el desarrollo del proyecto, y permite anticipar un análisis bien fundamentado y con valor práctico para Interconnect.
#
# </div>
